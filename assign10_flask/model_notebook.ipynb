# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('winequality-red.csv')

# %%
data
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
data.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
plt.figure(figsize=(15,10))
sns.heatmap(data.corr(),annot=True)
# Out:
# <Axes: >

# %%
#duplicates

# %%
data[data.duplicated()]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 4               7.4             0.700         0.00            1.90      0.076
# 11              7.5             0.500         0.36            6.10      0.071
# 27              7.9             0.430         0.21            1.60      0.106
# 40              7.3             0.450         0.36            5.90      0.074
# 65              7.2             0.725         0.05            4.65      0.086
# ...             ...               ...          ...             ...        ...
# 1563            7.2             0.695         0.13            2.00      0.076
# 1564            7.2             0.695         0.13            2.00      0.076
# 1567            7.2             0.695         0.13            2.00      0.076
# 1581            6.2             0.560         0.09            1.70      0.053
# 1596            6.3             0.510         0.13            2.30      0.076
#
# ...

# %%
data.iloc[1596]
# Out:
# fixed acidity            6.30000
# volatile acidity         0.51000
# citric acid              0.13000
# residual sugar           2.30000
# chlorides                0.07600
# free sulfur dioxide     29.00000
# total sulfur dioxide    40.00000
# density                  0.99574
# pH                       3.42000
# sulphates                0.75000
# alcohol                 11.00000
# quality                  6.00000
# Name: 1596, dtype: float64

# %%
data.drop_duplicates(inplace=True)

# %%
data.isna().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
data['quality'].mean()
# Out:
# 5.6232523914643116

# %%
X=data.drop('quality',axis=1)
y=data['quality']

# %%
X
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 5               7.4             0.660         0.00             1.8      0.075
# ...             ...               ...          ...             ...        ...
# 1593            6.8             0.620         0.08             1.9      0.068
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
y
# Out:
# 0       5
# 1       5
# 2       5
# 3       6
# 5       5
#        ..
# 1593    6
# 1594    5
# 1595    6
# 1597    5
# 1598    6
# Name: quality, Length: 1359, dtype: int64

# %%
#outlier

# %%
X_columns=X.columns
fig,axes=plt.subplots(4,3,figsize=(15,10))
col=0
for i in range(4):
  for j in range(3):
    sns.boxplot(X[X_columns[col]],ax=axes[i,j])
    col=col+1
    if col==len(X_columns):
      break
  if col==len(X_columns):
    break

# %%
X_columns=X.columns
fig,axes=plt.subplots(4,3,figsize=(15,15))
col=0
for i in range(4):
  for j in range(3):
    sns.histplot(X[X_columns[col]],ax=axes[i,j])
    col=col+1
    if col==len(X_columns):
      break
  if col==len(X_columns):
    break

# %%
#mode
"""
for col in X_columns:
  outlier_list=[]
  col_mode=X[col].mode()
  q1=np.percentile(X[col],25)
  q3=np.percentile(X[col],75)
  iqr=q3-q1
  upper=q3+iqr*1.5
  lower=q1-iqr*1.5
  outlier_list=X[(X[col]>upper)|(X[col]<lower)].index
  for i in outlier_list:
    X.loc[i,col]=col_mode[0]  

X_columns=X.columns
fig,axes=plt.subplots(4,3,figsize=(15,10))
col=0
for i in range(4):
  for j in range(3):
    sns.boxplot(X[X_columns[col]],ax=axes[i,j])
    col=col+1
    if col==len(X_columns):
      break
  if col==len(X_columns):
    break
"""
# Out:
# '\nfor col in X_columns:\n  outlier_list=[]\n  col_mode=X[col].mode()\n  q1=np.percentile(X[col],25)\n  q3=np.percentile(X[col],75)\n  iqr=q3-q1\n  upper=q3+iqr*1.5\n  lower=q1-iqr*1.5\n  outlier_list=X[(X[col]>upper)|(X[col]<lower)].index\n  for i in outlier_list:\n    X.loc[i,col]=col_mode[0]  \n\nX_columns=X.columns\nfig,axes=plt.subplots(4,3,figsize=(15,10))\ncol=0\nfor i in range(4):\n  for j in range(3):\n    sns.boxplot(X[X_columns[col]],ax=axes[i,j])\n    col=col+1\n    if col==len(X_columns):\n      break\n  if col==len(X_columns):\n    break\n'

# %%
#median
"""
for col in X_columns:
  outlier_list=[]
  col_median=X[col].median()
  q1=np.percentile(X[col],25)
  q3=np.percentile(X[col],75)
  iqr=q3-q1
  upper=q3+iqr*1.5
  lower=q1-iqr*1.5
  outlier_list=X[(X[col]>upper)|(X[col]<lower)].index
  for i in outlier_list:
    X.loc[i,col]=col_median
  
X_columns=X.columns
fig,axes=plt.subplots(4,3,figsize=(15,10))
col=0
for i in range(4):
  for j in range(3):
    sns.boxplot(X[X_columns[col]],ax=axes[i,j])
    col=col+1
    if col==len(X_columns):
      break
  if col==len(X_columns):
    break
  """
# Out:
# '\nfor col in X_columns:\n  outlier_list=[]\n  col_median=X[col].median()\n  q1=np.percentile(X[col],25)\n  q3=np.percentile(X[col],75)\n  iqr=q3-q1\n  upper=q3+iqr*1.5\n  lower=q1-iqr*1.5\n  outlier_list=X[(X[col]>upper)|(X[col]<lower)].index\n  for i in outlier_list:\n    X.loc[i,col]=col_median\n  \nX_columns=X.columns\nfig,axes=plt.subplots(4,3,figsize=(15,10))\ncol=0\nfor i in range(4):\n  for j in range(3):\n    sns.boxplot(X[X_columns[col]],ax=axes[i,j])\n    col=col+1\n    if col==len(X_columns):\n      break\n  if col==len(X_columns):\n    break\n  '

# %%
#mean

for col in X_columns:
  outlier_list=[]
  col_mean=X[col].mean()
  q1=np.percentile(X[col],25)
  q3=np.percentile(X[col],75)
  iqr=q3-q1
  upper=q3+iqr*1.5
  lower=q1-iqr*1.5
  outlier_list=X[(X[col]>upper)|(X[col]<lower)].index
  for i in outlier_list:
    X.loc[i,col]=col_mean
  
X_columns=X.columns
fig,axes=plt.subplots(4,3,figsize=(15,10))
col=0
for i in range(4):
  for j in range(3):
    sns.boxplot(X[X_columns[col]],ax=axes[i,j])
    col=col+1
    if col==len(X_columns):
      break
  if col==len(X_columns):
    break

# %%
X
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 5               7.4             0.660         0.00             1.8      0.075
# ...             ...               ...          ...             ...        ...
# 1593            6.8             0.620         0.08             1.9      0.068
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
#spliting

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test=train_test_split(X,y,random_state=42,test_size=0.25)

# %%
X_train
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 177        7.500000              0.52         0.42             2.3      0.087
# 1366       7.300000              0.74         0.08             1.7      0.094
# 617       11.500000              0.31         0.51             2.2      0.079
# 814        8.310596              0.41         0.54             2.8      0.103
# 1170       9.200000              0.36         0.34             1.6      0.062
# ...             ...               ...          ...             ...        ...
# 1285      11.300000              0.37         0.50             1.8      0.090
# 1329       7.400000              0.60         0.26             2.1      0.083
# 1526       6.800000              0.47         0.08             2.2      0.064
# 1011       8.900000              0.32         0.31             2.0      0.088
# 1322       9.100000              0.34         0.42             1.8      0.058
#
# ...

# %%
X_test
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 55              7.7          0.620000         0.04          2.5234   0.084000
# 1291            8.2          0.635000         0.10          2.1000   0.073000
# 1544            8.4          0.370000         0.43          2.3000   0.063000
# 593             9.9          0.490000         0.58          3.5000   0.094000
# 1261            6.3          0.529478         0.00          2.0000   0.083000
# ...             ...               ...          ...             ...        ...
# 106             7.8          0.410000         0.68          1.7000   0.088124
# 1064            8.2          0.740000         0.09          2.0000   0.067000
# 1439            7.3          0.670000         0.02          2.2000   0.072000
# 1098            8.0          0.310000         0.45          2.1000   0.088124
# 570            11.5          0.350000         0.49          3.3000   0.070000
#
# ...

# %%
y_test
# Out:
# 55      5
# 1291    6
# 1544    7
# 593     5
# 1261    4
#        ..
# 106     5
# 1064    6
# 1439    6
# 1098    7
# 570     6
# Name: quality, Length: 340, dtype: int64

# %%
y_train
# Out:
# 177     6
# 1366    5
# 617     6
# 814     6
# 1170    6
#        ..
# 1285    5
# 1329    6
# 1526    6
# 1011    6
# 1322    5
# Name: quality, Length: 1019, dtype: int64

# %%
data['quality'].value_counts()
# Out:
# quality
# 5    577
# 6    535
# 7    167
# 4     53
# 8     17
# 3     10
# Name: count, dtype: int64

# %%
#creating and evaluating model

# %%
from sklearn.metrics import mean_absolute_error,r2_score,mean_squared_error,mean_absolute_percentage_error,classification_report,confusion_matrix

# %%
#linear regression

from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(X_train,y_train)
lr_y_pred=lr.predict(X_test)
print("mean_absolute_error  : ",mean_absolute_error(y_test,lr_y_pred))
print("mean_squared_error   : ",mean_squared_error(y_test,lr_y_pred))
print("r2_score             : ",r2_score(y_test,lr_y_pred))
# Out:
# mean_absolute_error  :  0.4917445542310802
# mean_squared_error   :  0.41129984437132205
# r2_score             :  0.391454582568701

# %%
"""#logistic regression

from sklearn.linear_model import LogisticRegression
logr=LogisticRegression()
logr.fit(X_train,y_train)
logr_y_pred=logr.predict(X_test)
print(classification_report(y_test,logr_y_pred))
print(confusion_matrix(y_test,logr_y_pred))
print("mean_absolute_error  : ",mean_absolute_error(y_test,y_pred))
print("mean_squared_error   : ",mean_squared_error(y_test,y_pred))
print("r2_score             : ",r2_score(y_test,y_pred))
"""
# Out:
# '#logistic regression\n\nfrom sklearn.linear_model import LogisticRegression\nlogr=LogisticRegression()\nlogr.fit(X_train,y_train)\nlogr_y_pred=logr.predict(X_test)\nprint(classification_report(y_test,logr_y_pred))\nprint(confusion_matrix(y_test,logr_y_pred))\nprint("mean_absolute_error  : ",mean_absolute_error(y_test,y_pred))\nprint("mean_squared_error   : ",mean_squared_error(y_test,y_pred))\nprint("r2_score             : ",r2_score(y_test,y_pred))\n'

# %%
#knn
from sklearn.neighbors import KNeighborsRegressor
mean_squared_error_list=[]
for i in range(1,15):
  knr=KNeighborsRegressor(n_neighbors=i)
  knr.fit(X_train,y_train)
  y_pred=knr.predict(X_test)
  mean_squared_error_list.append(mean_squared_error(y_test,y_pred))
plt.plot(np.arange(1,15),mean_squared_error_list,'-o')

# %%
#knn
#from sklearn.neighbors import KNeighborsRegressor
r2_score_list=[]
for i in range(1,15):
  knr=KNeighborsRegressor(n_neighbors=i)
  knr.fit(X_train,y_train)
  y_pred=knr.predict(X_test)
  r2_score_list.append(r2_score(y_test,y_pred))
plt.plot(np.arange(1,15),r2_score_list,'-o')

# %%
mean_absolute_error_list=[]
for i in range(1,15):
  knr=KNeighborsRegressor(n_neighbors=i)
  knr.fit(X_train,y_train)
  y_pred=knr.predict(X_test)
  mean_absolute_error_list.append(mean_absolute_error(y_test,y_pred))
plt.plot(np.arange(1,15),mean_absolute_error_list,'-o')

# %%
from sklearn.neighbors import KNeighborsRegressor
knr=KNeighborsRegressor(n_neighbors=6)
knr.fit(X_train,y_train)
knr_y_pred=knr.predict(X_test)
print("mean_absolute_error  : ",mean_absolute_error(y_test,knr_y_pred))
print("mean_squared_error   : ",mean_squared_error(y_test,knr_y_pred))
print("r2_score             : ",r2_score(y_test,knr_y_pred))
# Out:
# mean_absolute_error  :  0.6259803921568627
# mean_squared_error   :  0.6554738562091502
# r2_score             :  0.030182926395697418

# %%
#svm
from sklearn.svm import SVR

svr=SVR()
svr.fit(X_train,y_train)
svr_y_pred=svr.predict(X_test)
print("mean_absolute_error  : ",mean_absolute_error(y_test,svr_y_pred))
print("mean_squared_error   : ",mean_squared_error(y_test,svr_y_pred))
print("r2_score             : ",r2_score(y_test,svr_y_pred))
# Out:
# mean_absolute_error  :  0.5680371531082623
# mean_squared_error   :  0.55726872044068
# r2_score             :  0.1754839425715452

# %%
#random forest
from sklearn.ensemble import RandomForestRegressor

rfr=RandomForestRegressor(random_state=42)
rfr.fit(X_train,y_train)
rfr_y_pred=rfr.predict(X_test)
print("mean_absolute_error  : ",mean_absolute_error(y_test,rfr_y_pred))
print("mean_squared_error   : ",mean_squared_error(y_test,rfr_y_pred))
print("r2_score             : ",r2_score(y_test,rfr_y_pred))
# Out:
# mean_absolute_error  :  0.4879705882352941
# mean_squared_error   :  0.4010479411764705
# r2_score             :  0.40662295375715163

# %%
metrics_df=pd.DataFrame(
  {'Model':['LinearRegression','KNeighborsRegressor','SVR','RandomForestRegressor'],
   'Mean_absolute_error':[mean_absolute_error(y_test,lr_y_pred),mean_absolute_error(y_test,knr_y_pred),mean_absolute_error(y_test,svr_y_pred),mean_absolute_error(y_test,rfr_y_pred)],
   'Mean_squared_error':[mean_squared_error(y_test,lr_y_pred),mean_squared_error(y_test,knr_y_pred),mean_squared_error(y_test,svr_y_pred),mean_squared_error(y_test,rfr_y_pred)],
   'R2-score':[r2_score(y_test,lr_y_pred),r2_score(y_test,knr_y_pred),r2_score(y_test,svr_y_pred),r2_score(y_test,rfr_y_pred)],}
)
metrics_df
# Out:
#                    Model  Mean_absolute_error  Mean_squared_error  R2-score
# 0       LinearRegression             0.491745            0.411300  0.391455
# 1    KNeighborsRegressor             0.625980            0.655474  0.030183
# 2                    SVR             0.568037            0.557269  0.175484
# 3  RandomForestRegressor             0.487971            0.401048  0.406623

# %%
X.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1359.000000       1359.000000  1359.000000     1359.000000
# mean        8.162203          0.521052     0.271797        2.219646
# std         1.495346          0.167497     0.194536        0.445846
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.000000          0.630000     0.430000        2.523400
# max        12.300000          1.010000     0.790000        3.650000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1359.000000          1359.000000           1359.000000  1359.000000
# mean      0.079370            15.215030             43.520728     0.996710
# std       0.015226             9.143147             27.260450     0.001650
# ...

# %%
from sklearn.preprocessing import StandardScaler

ssc=StandardScaler()
scaled_X_train=ssc.fit_transform(X_train)
scaled_X_train=pd.DataFrame(scaled_X_train,columns=X_train.columns)
scaled_X_test=ssc.transform(X_test)
scaled_X_test=pd.DataFrame(scaled_X_test,columns=X_test.columns)

# %%
X_train
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 177        7.500000              0.52         0.42             2.3      0.087
# 1366       7.300000              0.74         0.08             1.7      0.094
# 617       11.500000              0.31         0.51             2.2      0.079
# 814        8.310596              0.41         0.54             2.8      0.103
# 1170       9.200000              0.36         0.34             1.6      0.062
# ...             ...               ...          ...             ...        ...
# 1285      11.300000              0.37         0.50             1.8      0.090
# 1329       7.400000              0.60         0.26             2.1      0.083
# 1526       6.800000              0.47         0.08             2.2      0.064
# 1011       8.900000              0.32         0.31             2.0      0.088
# 1322       9.100000              0.34         0.42             1.8      0.058
#
# ...

# %%
scaled_X_train
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0         -0.454911         -0.002374     0.742934        0.149264   0.481015
# 1         -0.591504          1.329103    -1.001183       -1.203455   0.942751
# 2          2.276947         -1.273330     1.204612       -0.076189  -0.046682
# 3          0.098697         -0.668113     1.358504        1.276531   1.536410
# 4          0.706128         -0.970722     0.332553       -1.428909  -1.168039
# ...             ...               ...          ...             ...        ...
# 1014       2.140354         -0.910200     1.153314       -0.978002   0.678902
# 1015      -0.523208          0.481799    -0.077827       -0.301642   0.217166
# 1016      -0.932987         -0.304983    -1.001183       -0.076189  -1.036115
# 1017       0.501239         -1.212808     0.178661       -0.527096   0.546977
# 1018       0.637832         -1.091765     0.742934       -0.978002  -1.431888
#
# ...

# %%
lr_2=LinearRegression()
lr_2.fit(scaled_X_train,y_train)
lr_2_y_pred=lr_2.predict(scaled_X_test)
print("mean_absolute_error  : ",mean_absolute_error(y_test,lr_2_y_pred))
print("mean_squared_error   : ",mean_squared_error(y_test,lr_2_y_pred))
print("r2_score             : ",r2_score(y_test,lr_2_y_pred))
# Out:
# mean_absolute_error  :  0.49174455423108065
# mean_squared_error   :  0.4112998443713223
# r2_score             :  0.3914545825687006

# %%
knr_2=KNeighborsRegressor(n_neighbors=6)
knr_2.fit(scaled_X_train,y_train)
knr_2_y_pred=knr_2.predict(scaled_X_test)
print("mean_absolute_error  : ",mean_absolute_error(y_test,knr_2_y_pred))
print("mean_squared_error   : ",mean_squared_error(y_test,knr_2_y_pred))
print("r2_score             : ",r2_score(y_test,knr_2_y_pred))
# Out:
# mean_absolute_error  :  0.5240196078431373
# mean_squared_error   :  0.4741013071895425
# r2_score             :  0.2985356502398393

# %%
svr_2=SVR()
svr_2.fit(scaled_X_train,y_train)
svr_2_y_pred=svr_2.predict(scaled_X_test)
print("mean_absolute_error  : ",mean_absolute_error(y_test,svr_2_y_pred))
print("mean_squared_error   : ",mean_squared_error(y_test,svr_2_y_pred))
print("r2_score             : ",r2_score(y_test,svr_2_y_pred))
# Out:
# mean_absolute_error  :  0.4859255453292726
# mean_squared_error   :  0.4213958235395306
# r2_score             :  0.37651691132623755

# %%
metrics_df=pd.DataFrame(
  {'Model':['LinearRegression','KNeighborsRegressor','SVR','RandomForestRegressor','LinearRegression(scaled)','KNeighborsRegressor(scaled)','SVR(scaled)',],
   'Mean_absolute_error':[mean_absolute_error(y_test,lr_y_pred),mean_absolute_error(y_test,knr_y_pred),mean_absolute_error(y_test,svr_y_pred),mean_absolute_error(y_test,rfr_y_pred),mean_absolute_error(y_test,lr_2_y_pred),mean_absolute_error(y_test,knr_2_y_pred),mean_absolute_error(y_test,svr_2_y_pred)],
   'Mean_squared_error':[mean_squared_error(y_test,lr_y_pred),mean_squared_error(y_test,knr_y_pred),mean_squared_error(y_test,svr_y_pred),mean_squared_error(y_test,rfr_y_pred),mean_squared_error(y_test,lr_2_y_pred),mean_squared_error(y_test,knr_2_y_pred),mean_squared_error(y_test,svr_2_y_pred)],
   'R2-score':[r2_score(y_test,lr_y_pred),r2_score(y_test,knr_y_pred),r2_score(y_test,svr_y_pred),r2_score(y_test,rfr_y_pred),r2_score(y_test,lr_2_y_pred),r2_score(y_test,knr_2_y_pred),r2_score(y_test,svr_2_y_pred)],
   }
)
metrics_df
# Out:
#                          Model  Mean_absolute_error  Mean_squared_error  \
# 0             LinearRegression             0.491745            0.411300
# 1          KNeighborsRegressor             0.625980            0.655474
# 2                          SVR             0.568037            0.557269
# 3        RandomForestRegressor             0.487971            0.401048
# 4     LinearRegression(scaled)             0.491745            0.411300
# 5  KNeighborsRegressor(scaled)             0.524020            0.474101
# 6                  SVR(scaled)             0.485926            0.421396
#
#    R2-score
# 0  0.391455
# 1  0.030183
# 2  0.175484
# 3  0.406623
# 4  0.391455
# 5  0.298536
# 6  0.376517

# %%
metrics_df['Mean_absolute_error'].sort_values()
# Out:
# 6    0.485926
# 3    0.487971
# 0    0.491745
# 4    0.491745
# 5    0.524020
# 2    0.568037
# 1    0.625980
# Name: Mean_absolute_error, dtype: float64

# %%
metrics_df['Mean_squared_error'].sort_values()
# Out:
# 3    0.401048
# 0    0.411300
# 4    0.411300
# 6    0.421396
# 5    0.474101
# 2    0.557269
# 1    0.655474
# Name: Mean_squared_error, dtype: float64

# %%
metrics_df['R2-score'].sort_values(ascending=False)
# Out:
# 3    0.406623
# 0    0.391455
# 4    0.391455
# 6    0.376517
# 5    0.298536
# 2    0.175484
# 1    0.030183
# Name: R2-score, dtype: float64

# %%
"""

Model	Mean_absolute_error	Mean_squared_error	R2-score
0	LinearRegression	          0.491745	0.411300	0.391455
1	KNeighborsRegressor	        0.625980	0.655474	0.030183
2	SVR	                        0.568037	0.557269	0.175484
3	RandomForestRegressor	      0.486471	0.403092	0.403598
4	LinearRegression(scaled)	  0.491745	0.411300	0.391455
5	KNeighborsRegressor(scaled)	0.524020	0.474101	0.298536
6	SVR(scaled)	                0.485926	0.421396	0.376517

metrics_df['Mean_absolute_error'].sort_values()
6    0.485926
3    0.486471
0    0.491745
4    0.491745
5    0.524020
2    0.568037
1    0.625980
Name: Mean_absolute_error, dtype: float64

metrics_df['Mean_squared_error'].sort_values()
3    0.403092
0    0.411300
4    0.411300
6    0.421396
5    0.474101
2    0.557269
1    0.655474
Name: Mean_squared_error, dtype: float64


metrics_df['R2-score'].sort_values(ascending=False)
3    0.403598
0    0.391455
4    0.391455
6    0.376517
5    0.298536
2    0.175484
1    0.030183
Name: R2-score, dtype: float64
"""
# Out:
# "\n\nModel\tMean_absolute_error\tMean_squared_error\tR2-score\n0\tLinearRegression\t          0.491745\t0.411300\t0.391455\n1\tKNeighborsRegressor\t        0.625980\t0.655474\t0.030183\n2\tSVR\t                        0.568037\t0.557269\t0.175484\n3\tRandomForestRegressor\t      0.486471\t0.403092\t0.403598\n4\tLinearRegression(scaled)\t  0.491745\t0.411300\t0.391455\n5\tKNeighborsRegressor(scaled)\t0.524020\t0.474101\t0.298536\n6\tSVR(scaled)\t                0.485926\t0.421396\t0.376517\n\nmetrics_df['Mean_absolute_error'].sort_values()\n6    0.485926\n3    0.486471\n0    0.491745\n4    0.491745\n5    0.524020\n2    0.568037\n1    0.625980\nName: Mean_absolute_error, dtype: float64\n\nmetrics_df['Mean_squared_error'].sort_values()\n3    0.403092\n0    0.411300\n4    0.411300\n6    0.421396\n5    0.474101\n2    0.557269\n1    0.655474\nName: Mean_squared_error, dtype: float64\n\n\nmetrics_df['R2-score'].sort_values(ascending=False)\n3    0.403598\n0    0.391455\n4    0.391455\n6    
# ...

# %%
"""
lr:17
knn:3
svr:6
rfr:20
lr(s):14
knn(s):9
svr(s):15
"""
# Out:
# '\nlr:17\nknn:3\nsvr:6\nrfr:20\nlr(s):14\nknn(s):9\nsvr(s):15\n'

# %%
X_test.shape
# Out:
# (340, 11)

# %%
X.iloc[20]
# Out:
# fixed acidity            7.9000
# volatile acidity         0.4300
# citric acid              0.2100
# residual sugar           1.6000
# chlorides                0.1060
# free sulfur dioxide     10.0000
# total sulfur dioxide    37.0000
# density                  0.9966
# pH                       3.1700
# sulphates                0.9100
# alcohol                  9.5000
# Name: 22, dtype: float64

# %%
X.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1359.000000       1359.000000  1359.000000     1359.000000
# mean        8.162203          0.521052     0.271797        2.219646
# std         1.495346          0.167497     0.194536        0.445846
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.000000          0.630000     0.430000        2.523400
# max        12.300000          1.010000     0.790000        3.650000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1359.000000          1359.000000           1359.000000  1359.000000
# mean      0.079370            15.215030             43.520728     0.996710
# std       0.015226             9.143147             27.260450     0.001650
# ...

# %%
threshold = data['quality'].mean()
threshold
# Out:
# 5.6232523914643116

# %%
prediction_value=[7.600,0.4900,0.2122,1.222,0.1000,30,40,1,3.3,0.67,4]
print(prediction_value)
prediction_value=np.reshape(prediction_value,(1,11))
print(prediction_value)
# Out:
# [7.6, 0.49, 0.2122, 1.222, 0.1, 30, 40, 1, 3.3, 0.67, 4]
# [[ 7.6     0.49    0.2122  1.222   0.1    30.     40.      1.      3.3
#    0.67    4.    ]]

# %%
pred=rfr.predict(prediction_value)
print(pred)
if pred>threshold:
  print("THE WINE IS BOUGHT")
else:
  print("THE WINE IS NOT BOUGHT")
# Out:
# [4.51]
# THE WINE IS NOT BOUGHT
# f:\EDU CODING\PYTHON STP\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(

# %%
X.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol'],
#       dtype='object')

# %%
X.describe().loc[['min','max']]
# Out:
#      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# min            4.6              0.12         0.00            0.90      0.039
# max           12.3              1.01         0.79            3.65      0.122
#
#      free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# min                  1.0                   6.0  0.99235  2.93       0.33
# max                 42.0                 124.0  1.00100  3.68       0.99
#
#      alcohol
# min      8.4
# max     13.5

# %%
X.describe().loc['min']
# Out:
# fixed acidity           4.60000
# volatile acidity        0.12000
# citric acid             0.00000
# residual sugar          0.90000
# chlorides               0.03900
# free sulfur dioxide     1.00000
# total sulfur dioxide    6.00000
# density                 0.99235
# pH                      2.93000
# sulphates               0.33000
# alcohol                 8.40000
# Name: min, dtype: float64

# %%
X.describe().loc['max']
# Out:
# fixed acidity            12.300
# volatile acidity          1.010
# citric acid               0.790
# residual sugar            3.650
# chlorides                 0.122
# free sulfur dioxide      42.000
# total sulfur dioxide    124.000
# density                   1.001
# pH                        3.680
# sulphates                 0.990
# alcohol                  13.500
# Name: max, dtype: float64

# %%
X_describe=X.describe()
X_describe
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1359.000000       1359.000000  1359.000000     1359.000000
# mean        8.162203          0.521052     0.271797        2.219646
# std         1.495346          0.167497     0.194536        0.445846
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.000000          0.630000     0.430000        2.523400
# max        12.300000          1.010000     0.790000        3.650000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1359.000000          1359.000000           1359.000000  1359.000000
# mean      0.079370            15.215030             43.520728     0.996710
# std       0.015226             9.143147             27.260450     0.001650
# ...

# %%
X_describe['fixed acidity'].loc['mean']
# Out:
# 8.162203412131047

# %%
min_max_dict_temp={}

for col in X_columns:
  print(col)
  #print(X_describe[col].loc['min'])
  min=X_describe[col].loc['min']
  max=X_describe[col].loc['max']
  min_max_dict_temp[col]=[min,max]
min_max_dict_temp
# Out:
# fixed acidity
# volatile acidity
# citric acid
# residual sugar
# chlorides
# free sulfur dioxide
# total sulfur dioxide
# density
# pH
# sulphates
# alcohol
# {'fixed acidity': [4.6, 12.3],
#  'volatile acidity': [0.12, 1.01],
#  'citric acid': [0.0, 0.79],
#  'residual sugar': [0.9, 3.65],
#  'chlorides': [0.039, 0.122],
#  'free sulfur dioxide': [1.0, 42.0],
#  'total sulfur dioxide': [6.0, 124.0],
#  'density': [0.99235, 1.001],
#  'pH': [2.93, 3.68],
#  'sulphates': [0.33, 0.99],
#  'alcohol': [8.4, 13.5]}

# %%
min_max_dict={}
import math
for col in X_columns:
  print(col)
  #print(X_describe[col].loc['min'])
  min=math.floor(X_describe[col].loc['min'])
  max=math.ceil(X_describe[col].loc['max'])
  min_max_dict[col]=[min,max]
min_max_dict
# Out:
# fixed acidity
# volatile acidity
# citric acid
# residual sugar
# chlorides
# free sulfur dioxide
# total sulfur dioxide
# density
# pH
# sulphates
# alcohol
# {'fixed acidity': [4, 13],
#  'volatile acidity': [0, 2],
#  'citric acid': [0, 1],
#  'residual sugar': [0, 4],
#  'chlorides': [0, 1],
#  'free sulfur dioxide': [1, 42],
#  'total sulfur dioxide': [6, 124],
#  'density': [0, 2],
#  'pH': [2, 4],
#  'sulphates': [0, 1],
#  'alcohol': [8, 14]}

# %%
X.describe().loc[['min','max']]
# Out:
#      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# min            4.6              0.12         0.00            0.90      0.039
# max           12.3              1.01         0.79            3.65      0.122
#
#      free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# min                  1.0                   6.0  0.99235  2.93       0.33
# max                 42.0                 124.0  1.00100  3.68       0.99
#
#      alcohol
# min      8.4
# max     13.5

# %%
min_max_dict_temp
# Out:
# {'fixed acidity': [4.6, 12.3],
#  'volatile acidity': [0.12, 1.01],
#  'citric acid': [0.0, 0.79],
#  'residual sugar': [0.9, 3.65],
#  'chlorides': [0.039, 0.122],
#  'free sulfur dioxide': [1.0, 42.0],
#  'total sulfur dioxide': [6.0, 124.0],
#  'density': [0.99235, 1.001],
#  'pH': [2.93, 3.68],
#  'sulphates': [0.33, 0.99],
#  'alcohol': [8.4, 13.5]}

# %%
min_max_dict
# Out:
# {'fixed acidity': [4, 13],
#  'volatile acidity': [0, 2],
#  'citric acid': [0, 1],
#  'residual sugar': [0, 4],
#  'chlorides': [0, 1],
#  'free sulfur dioxide': [1, 42],
#  'total sulfur dioxide': [6, 124],
#  'density': [0, 2],
#  'pH': [2, 4],
#  'sulphates': [0, 1],
#  'alcohol': [8, 14]}

# %%
"""import pickle 

with open("model.pkl","wb") as f:
  pickle.dump(rfr,f)"""

# %%
#done

# %%
"""
model2=pickle.load(open("model_rfr.pkl","rb"))
pred=model2.predict(prediction_value)
print(pred)
if pred>threshold:
  print("THE WINE IS BOUGHT")
else:
  print("THE WINE IS NOT BOUGHT")

model2=pickle.load(open("model_rfr.pkl","rb"))


  """
# Out:
# [4.51]
# THE WINE IS NOT BOUGHT
# f:\EDU CODING\PYTHON STP\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(

# %%
"""
model2_y_pred=model2.predict(X_test)

metrics_df=pd.DataFrame(
  {'Model':['LinearRegression','KNeighborsRegressor','SVR','RandomForestRegressor','LinearRegression(scaled)','KNeighborsRegressor(scaled)','SVR(scaled)','Exportedmodel(rfr)'],
   'Mean_absolute_error':[mean_absolute_error(y_test,lr_y_pred),mean_absolute_error(y_test,knr_y_pred),mean_absolute_error(y_test,svr_y_pred),mean_absolute_error(y_test,rfr_y_pred),mean_absolute_error(y_test,lr_2_y_pred),mean_absolute_error(y_test,knr_2_y_pred),mean_absolute_error(y_test,svr_2_y_pred),mean_absolute_error(y_test,model2_y_pred)],
   'Mean_squared_error':[mean_squared_error(y_test,lr_y_pred),mean_squared_error(y_test,knr_y_pred),mean_squared_error(y_test,svr_y_pred),mean_squared_error(y_test,rfr_y_pred),mean_squared_error(y_test,lr_2_y_pred),mean_squared_error(y_test,knr_2_y_pred),mean_squared_error(y_test,svr_2_y_pred),mean_squared_error(y_test,model2_y_pred)],
   'R2-score':[r2_score(y_test,lr_y_pred),r2_score(y_test,knr_y_pred),r2_score(y_test,svr_y_pred),r2_score(y_test,rfr_y_pred),r2_score(y_test,lr_2_y_pred),r2_score(y_test,knr_2_y_pred),r2_score(y_test,svr_2_y_pred),r2_score(y_test,model2_y_pred)],
   }
)
metrics_df"""
# Out:
#                          Model  Mean_absolute_error  Mean_squared_error  \
# 0             LinearRegression             0.491745            0.411300
# 1          KNeighborsRegressor             0.625980            0.655474
# 2                          SVR             0.568037            0.557269
# 3        RandomForestRegressor             0.487971            0.401048
# 4     LinearRegression(scaled)             0.491745            0.411300
# 5  KNeighborsRegressor(scaled)             0.524020            0.474101
# 6                  SVR(scaled)             0.485926            0.421396
# 7           Exportedmodel(rfr)             0.487971            0.401048
#
#    R2-score
# 0  0.391455
# 1  0.030183
# 2  0.175484
# 3  0.406623
# 4  0.391455
# 5  0.298536
# 6  0.376517
# 7  0.406623
