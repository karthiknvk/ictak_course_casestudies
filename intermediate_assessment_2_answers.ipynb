# %% [markdown]
# <h1>INTERMEDIATE ASSESSMENT 2</h1>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# <h3>TRAIN DATA</h3>

# %%
data=pd.read_csv('train_LZdllcl.csv')

# %%
data
# Out:
#        employee_id         department     region         education gender  \
# 0            65438  Sales & Marketing   region_7  Master's & above      f
# 1            65141         Operations  region_22        Bachelor's      m
# 2             7513  Sales & Marketing  region_19        Bachelor's      m
# 3             2542  Sales & Marketing  region_23        Bachelor's      m
# 4            48945         Technology  region_26        Bachelor's      m
# ...            ...                ...        ...               ...    ...
# 54803         3030         Technology  region_14        Bachelor's      m
# 54804        74592         Operations  region_27  Master's & above      f
# 54805        13918          Analytics   region_1        Bachelor's      m
# 54806        13614  Sales & Marketing   region_9               NaN      m
# 54807        51526                 HR  region_22        Bachelor's      m
#
#       recruitment_channel  no_of_trainings  age  previous_year_rating  \
# ...

# %%
data['is_promoted'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
data['employee_id'].nunique()
# Out:
# 54808

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54808 entries, 0 to 54807
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   employee_id           54808 non-null  int64
#  1   department            54808 non-null  object
#  2   region                54808 non-null  object
#  3   education             52399 non-null  object
#  4   gender                54808 non-null  object
#  5   recruitment_channel   54808 non-null  object
#  6   no_of_trainings       54808 non-null  int64
#  7   age                   54808 non-null  int64
#  8   previous_year_rating  50684 non-null  float64
#  9   length_of_service     54808 non-null  int64
#  10  KPIs_met >80%         54808 non-null  int64
#  11  awards_won?           54808 non-null  int64
#  12  avg_training_score    54808 non-null  int64
#  13  is_promoted           54808 non-null  int64
# dtypes: float64(1), int64(8), object(5)
# ...

# %%
data.describe()
# Out:
#         employee_id  no_of_trainings           age  previous_year_rating  \
# count  54808.000000     54808.000000  54808.000000          50684.000000
# mean   39195.830627         1.253011     34.803915              3.329256
# std    22586.581449         0.609264      7.660169              1.259993
# min        1.000000         1.000000     20.000000              1.000000
# 25%    19669.750000         1.000000     29.000000              3.000000
# 50%    39225.500000         1.000000     33.000000              3.000000
# 75%    58730.500000         1.000000     39.000000              4.000000
# max    78298.000000        10.000000     60.000000              5.000000
#
#        length_of_service  KPIs_met >80%   awards_won?  avg_training_score  \
# count       54808.000000   54808.000000  54808.000000        54808.000000
# mean            5.865512       0.351974      0.023172           63.386750
# std             4.265094       0.477590      0.150450           13.371559
# ...

# %%
data.isna().sum()
# Out:
# employee_id                0
# department                 0
# region                     0
# education               2409
# gender                     0
# recruitment_channel        0
# no_of_trainings            0
# age                        0
# previous_year_rating    4124
# length_of_service          0
# KPIs_met >80%              0
# awards_won?                0
# avg_training_score         0
# is_promoted                0
# dtype: int64

# %% [markdown]
# <h4>EDA(BEFORE PREPROCESSING)</h4>

# %%
sns.countplot(x=data['is_promoted'])
# Out:
# <Axes: xlabel='is_promoted', ylabel='count'>

# %%
plt.figure(figsize=(12,10))
sns.heatmap(data.corr(numeric_only=True),annot=True,cmap='hot')
plt.show()

# %%
plt.figure(figsize=(12,10))
sns.boxplot(data.drop('employee_id',axis=1))
plt.xticks(rotation=90)
# Out:
# ([0, 1, 2, 3, 4, 5, 6, 7],
#  [Text(0, 0, 'no_of_trainings'),
#   Text(1, 0, 'age'),
#   Text(2, 0, 'previous_year_rating'),
#   Text(3, 0, 'length_of_service'),
#   Text(4, 0, 'KPIs_met >80%'),
#   Text(5, 0, 'awards_won?'),
#   Text(6, 0, 'avg_training_score'),
#   Text(7, 0, 'is_promoted')])

# %% [markdown]
# <h4>PREPROCESSING</h4>

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [employee_id, department, region, education, gender, recruitment_channel, no_of_trainings, age, previous_year_rating, length_of_service, KPIs_met >80%, awards_won?, avg_training_score, is_promoted]
# Index: []

# %%
#REMOVING COLUMNS

# %%
data.drop('employee_id',axis=1,inplace=True)

# %%
#FILLING MISSING VALUES

# %%
data.isna().sum()
# Out:
# department                 0
# region                     0
# education               2409
# gender                     0
# recruitment_channel        0
# no_of_trainings            0
# age                        0
# previous_year_rating    4124
# length_of_service          0
# KPIs_met >80%              0
# awards_won?                0
# avg_training_score         0
# is_promoted                0
# dtype: int64

# %%
data['education'].nunique()
# Out:
# 3

# %%
print(data['education'].value_counts())
# Out:
# education
# Bachelor's          36669
# Master's & above    14925
# Below Secondary       805
# Name: count, dtype: int64

# %%
sns.countplot(x=data['education'])
# Out:
# <Axes: xlabel='education', ylabel='count'>

# %%
data[data['education'].isna()]
# Out:
#               department     region education gender recruitment_channel  \
# 10            Technology  region_23       NaN      m            sourcing
# 21            Operations  region_15       NaN      m            sourcing
# 32     Sales & Marketing   region_7       NaN      f            sourcing
# 43     Sales & Marketing   region_2       NaN      m               other
# 82     Sales & Marketing   region_2       NaN      m            sourcing
# ...                  ...        ...       ...    ...                 ...
# 54692  Sales & Marketing   region_2       NaN      f            sourcing
# 54717          Analytics   region_2       NaN      m            sourcing
# 54729                 HR   region_2       NaN      f               other
# 54742  Sales & Marketing  region_31       NaN      m               other
# 54806  Sales & Marketing   region_9       NaN      m            sourcing
#
#        no_of_trainings  age  previous_year_rating  length_of_service  \
# ...

# %%
data['education']=data['education'].fillna(data['education'].mode()[0])

# %%
data.isna().sum()
# Out:
# department                 0
# region                     0
# education                  0
# gender                     0
# recruitment_channel        0
# no_of_trainings            0
# age                        0
# previous_year_rating    4124
# length_of_service          0
# KPIs_met >80%              0
# awards_won?                0
# avg_training_score         0
# is_promoted                0
# dtype: int64

# %%
data['previous_year_rating'].nunique()
# Out:
# 5

# %%
sns.countplot(x=data['previous_year_rating'])
# Out:
# <Axes: xlabel='previous_year_rating', ylabel='count'>

# %%
data['previous_year_rating']=data['previous_year_rating'].fillna(data['previous_year_rating'].mode()[0])

# %%
data.isna().sum()
# Out:
# department              0
# region                  0
# education               0
# gender                  0
# recruitment_channel     0
# no_of_trainings         0
# age                     0
# previous_year_rating    0
# length_of_service       0
# KPIs_met >80%           0
# awards_won?             0
# avg_training_score      0
# is_promoted             0
# dtype: int64

# %%
#OUTLIER DETECTION

# %%
plt.figure(figsize=(12,10))
sns.boxplot(data)
plt.xticks(rotation=90)
# Out:
# ([0, 1, 2, 3, 4, 5, 6, 7],
#  [Text(0, 0, 'no_of_trainings'),
#   Text(1, 0, 'age'),
#   Text(2, 0, 'previous_year_rating'),
#   Text(3, 0, 'length_of_service'),
#   Text(4, 0, 'KPIs_met >80%'),
#   Text(5, 0, 'awards_won?'),
#   Text(6, 0, 'avg_training_score'),
#   Text(7, 0, 'is_promoted')])

# %%
sns.boxplot(data['age'])
# Out:
# <Axes: ylabel='age'>

# %%
plt.hist(data['age'])
# Out:
# (array([  870.,  7031., 13751., 12531.,  8300.,  5093.,  2861.,  1908.,
#          1322.,  1141.]),
#  array([20., 24., 28., 32., 36., 40., 44., 48., 52., 56., 60.]),
#  <BarContainer object of 10 artists>)

# %%
data['age'].median()
# Out:
# 33.0

# %%
q1=np.percentile(data['age'],25)
q3=np.percentile(data['age'],75)
iqr=q3-q1
upper=q3+iqr*1.5
lower=q1-iqr*1.5
outlier_list=data[(data['age']>upper)|(data['age']<lower)].index
column_median=data['age'].median()
for i in outlier_list:
  data.loc[i,'age']=column_median

# %%
sns.boxplot(data['age'])
# Out:
# <Axes: ylabel='age'>

# %%
sns.boxplot(data['length_of_service'])
# Out:
# <Axes: ylabel='length_of_service'>

# %%
plt.hist(data['length_of_service'])
# Out:
# (array([2.510e+04, 1.900e+04, 5.738e+03, 2.623e+03, 1.372e+03, 5.960e+02,
#         2.270e+02, 9.600e+01, 5.100e+01, 5.000e+00]),
#  array([ 1. ,  4.6,  8.2, 11.8, 15.4, 19. , 22.6, 26.2, 29.8, 33.4, 37. ]),
#  <BarContainer object of 10 artists>)

# %%
data['length_of_service'].median()
# Out:
# 5.0

# %%
q1=np.percentile(data['length_of_service'],25)
q3=np.percentile(data['length_of_service'],75)
iqr=q3-q1
upper=q3+iqr*1.5
lower=q1-iqr*1.5
outlier_list=data[(data['length_of_service']>upper)|(data['length_of_service']<lower)].index
column_median=data['length_of_service'].median()
for i in outlier_list:
  data.loc[i,'length_of_service']=column_median

# %%
sns.boxplot(data['length_of_service'])
# Out:
# <Axes: ylabel='length_of_service'>

# %%
#ENCODING

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54808 entries, 0 to 54807
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   department            54808 non-null  object
#  1   region                54808 non-null  object
#  2   education             54808 non-null  object
#  3   gender                54808 non-null  object
#  4   recruitment_channel   54808 non-null  object
#  5   no_of_trainings       54808 non-null  int64
#  6   age                   54808 non-null  int64
#  7   previous_year_rating  54808 non-null  float64
#  8   length_of_service     54808 non-null  int64
#  9   KPIs_met >80%         54808 non-null  int64
#  10  awards_won?           54808 non-null  int64
#  11  avg_training_score    54808 non-null  int64
#  12  is_promoted           54808 non-null  int64
# dtypes: float64(1), int64(7), object(5)
# memory usage: 5.4+ MB

# %%
data['department'].nunique()
# Out:
# 9

# %%
data['region'].nunique()
# Out:
# 34

# %%
data['education'].nunique()
# Out:
# 3

# %%
data['gender'].nunique()
# Out:
# 2

# %%
data['recruitment_channel'].nunique()
# Out:
# 3

# %%
data
# Out:
#               department     region         education gender  \
# 0      Sales & Marketing   region_7  Master's & above      f
# 1             Operations  region_22        Bachelor's      m
# 2      Sales & Marketing  region_19        Bachelor's      m
# 3      Sales & Marketing  region_23        Bachelor's      m
# 4             Technology  region_26        Bachelor's      m
# ...                  ...        ...               ...    ...
# 54803         Technology  region_14        Bachelor's      m
# 54804         Operations  region_27  Master's & above      f
# 54805          Analytics   region_1        Bachelor's      m
# 54806  Sales & Marketing   region_9        Bachelor's      m
# 54807                 HR  region_22        Bachelor's      m
#
#       recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 0                sourcing                1   35                   5.0
# 1                   other                1   30                   5.0
# ...

# %%
data.drop('region',axis=1,inplace=True)

# %%
data
# Out:
#               department         education gender recruitment_channel  \
# 0      Sales & Marketing  Master's & above      f            sourcing
# 1             Operations        Bachelor's      m               other
# 2      Sales & Marketing        Bachelor's      m            sourcing
# 3      Sales & Marketing        Bachelor's      m               other
# 4             Technology        Bachelor's      m               other
# ...                  ...               ...    ...                 ...
# 54803         Technology        Bachelor's      m            sourcing
# 54804         Operations  Master's & above      f               other
# 54805          Analytics        Bachelor's      m               other
# 54806  Sales & Marketing        Bachelor's      m            sourcing
# 54807                 HR        Bachelor's      m               other
#
#        no_of_trainings  age  previous_year_rating  length_of_service  \
# ...

# %%
data=pd.get_dummies(data)

# %%
data
# Out:
#        no_of_trainings  age  previous_year_rating  length_of_service  \
# 0                    1   35                   5.0                  8
# 1                    1   30                   5.0                  4
# 2                    1   34                   3.0                  7
# 3                    2   39                   1.0                 10
# 4                    1   45                   3.0                  2
# ...                ...  ...                   ...                ...
# 54803                1   48                   3.0                  5
# 54804                1   37                   2.0                  6
# 54805                1   27                   5.0                  3
# 54806                1   29                   1.0                  2
# 54807                1   27                   1.0                  5
#
#        KPIs_met >80%  awards_won?  avg_training_score  is_promoted  \
# 0                  1            0                  49            0
# ...

# %%
#SPLITTING ITNO FEATURE AND TARGET SETS

# %%
data
# Out:
#        no_of_trainings  age  previous_year_rating  length_of_service  \
# 0                    1   35                   5.0                  8
# 1                    1   30                   5.0                  4
# 2                    1   34                   3.0                  7
# 3                    2   39                   1.0                 10
# 4                    1   45                   3.0                  2
# ...                ...  ...                   ...                ...
# 54803                1   48                   3.0                  5
# 54804                1   37                   2.0                  6
# 54805                1   27                   5.0                  3
# 54806                1   29                   1.0                  2
# 54807                1   27                   1.0                  5
#
#        KPIs_met >80%  awards_won?  avg_training_score  is_promoted  \
# 0                  1            0                  49            0
# ...

# %%
X=data.drop('is_promoted',axis=1)
y=data['is_promoted']

# %%
X
# Out:
#        no_of_trainings  age  previous_year_rating  length_of_service  \
# 0                    1   35                   5.0                  8
# 1                    1   30                   5.0                  4
# 2                    1   34                   3.0                  7
# 3                    2   39                   1.0                 10
# 4                    1   45                   3.0                  2
# ...                ...  ...                   ...                ...
# 54803                1   48                   3.0                  5
# 54804                1   37                   2.0                  6
# 54805                1   27                   5.0                  3
# 54806                1   29                   1.0                  2
# 54807                1   27                   1.0                  5
#
#        KPIs_met >80%  awards_won?  avg_training_score  department_Analytics  \
# ...

# %%
y
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 54803    0
# 54804    0
# 54805    0
# 54806    0
# 54807    0
# Name: is_promoted, Length: 54808, dtype: int64

# %%
#SCALING

# %%
from sklearn.preprocessing import StandardScaler

sc=StandardScaler()

# %%
X_columns=X.columns

# %%
X_columns
# Out:
# Index(['no_of_trainings', 'age', 'previous_year_rating', 'length_of_service',
#        'KPIs_met >80%', 'awards_won?', 'avg_training_score',
#        'department_Analytics', 'department_Finance', 'department_HR',
#        'department_Legal', 'department_Operations', 'department_Procurement',
#        'department_R&D', 'department_Sales & Marketing',
#        'department_Technology', 'education_Bachelor's',
#        'education_Below Secondary', 'education_Master's & above', 'gender_f',
#        'gender_m', 'recruitment_channel_other', 'recruitment_channel_referred',
#        'recruitment_channel_sourcing'],
#       dtype='object')

# %%
X=sc.fit_transform(X)
X
# Out:
# array([[-0.41527615,  0.12403271,  1.39576589, ..., -1.11791466,
#         -0.14587586,  1.16635286],
#        [-0.41527615, -0.62108258,  1.39576589, ...,  0.89452266,
#         -0.14587586, -0.85737347],
#        [-0.41527615, -0.02499035, -0.25065148, ..., -1.11791466,
#         -0.14587586,  1.16635286],
#        ...,
#        [-0.41527615, -1.06815175,  1.39576589, ...,  0.89452266,
#         -0.14587586, -0.85737347],
#        [-0.41527615, -0.77010564, -1.89706886, ..., -1.11791466,
#         -0.14587586,  1.16635286],
#        [-0.41527615, -1.06815175, -1.89706886, ...,  0.89452266,
#         -0.14587586, -0.85737347]])

# %%
X=pd.DataFrame(X,columns=X_columns)
X
# Out:
#        no_of_trainings       age  previous_year_rating  length_of_service  \
# 0            -0.415276  0.124033              1.395766           1.045077
# 1            -0.415276 -0.621083              1.395766          -0.377551
# 2            -0.415276 -0.024990             -0.250651           0.689420
# 3             1.226063  0.720125             -1.897069           1.756391
# 4            -0.415276  1.614263             -0.250651          -1.088866
# ...                ...       ...                   ...                ...
# 54803        -0.415276  2.061332             -0.250651          -0.021894
# 54804        -0.415276  0.422079             -1.073860           0.333763
# 54805        -0.415276 -1.068152              1.395766          -0.733209
# 54806        -0.415276 -0.770106             -1.897069          -1.088866
# 54807        -0.415276 -1.068152             -1.897069          -0.021894
#
#        KPIs_met >80%  awards_won?  avg_training_score  department_Analytics  \
# ...

# %% [markdown]
# <h4>SPLITTING DATA</h4>

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42,stratify=y)

# %% [markdown]
# <h4>TRAINING MODEL (with fine tuning)</h4>

# %%
from sklearn.metrics import f1_score,classification_report,confusion_matrix

# %% [markdown]
# #LOGISTIC REGRESSION

# %%
from sklearn.linear_model import LogisticRegression

lr_model=LogisticRegression()
lr_model.fit(X_train,y_train)
lr_model_y_pred=lr_model.predict(X_test)
print("f1 score : ",f1_score(y_test,lr_model_y_pred))
print(classification_report(y_test,lr_model_y_pred))
print(confusion_matrix(y_test,lr_model_y_pred))
# Out:
# f1 score :  0.40584415584415584
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.96     15043
#            1       0.84      0.27      0.41      1400
#
#     accuracy                           0.93     16443
#    macro avg       0.89      0.63      0.69     16443
# weighted avg       0.93      0.93      0.92     16443
#
# [[14970    73]
#  [ 1025   375]]

# %% [markdown]
# #KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

f1_score_list=[]
for i in range(1,15):
  knn_model=KNeighborsClassifier(n_neighbors=i,metric='minkowski')
  knn_model.fit(X_train,y_train)
  knn_model_y_pred=knn_model.predict(X_test)
  f1_score_list.append(f1_score(y_test,knn_model_y_pred))

# %%
plt.plot(np.arange(1,15),f1_score_list,'-o')
plt.show()

# %%
knn_model=KNeighborsClassifier(n_neighbors=3,metric='minkowski')
knn_model.fit(X_train,y_train)
knn_model_y_pred=knn_model.predict(X_test)
print("f1 score : ",f1_score(y_test,knn_model_y_pred))
print(classification_report(y_test,knn_model_y_pred))
print(confusion_matrix(y_test,knn_model_y_pred))
# Out:
# f1 score :  0.31781084973595775
#               precision    recall  f1-score   support
#
#            0       0.93      0.98      0.95     15043
#            1       0.48      0.24      0.32      1400
#
#     accuracy                           0.91     16443
#    macro avg       0.71      0.61      0.64     16443
# weighted avg       0.89      0.91      0.90     16443
#
# [[14691   352]
#  [ 1069   331]]

# %% [markdown]
# #SVM

# %%
from sklearn.svm import SVC


#linear kernel
svc_model=SVC(kernel='linear')
svc_model.fit(X_train,y_train)
svc_model_y_pred=svc_model.predict(X_test)
print("f1 score : ",f1_score(y_test,svc_model_y_pred))
print(classification_report(y_test,svc_model_y_pred))
print(confusion_matrix(y_test,svc_model_y_pred))
# Out:
# f1 score :  0.2256020278833967
#               precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96     15043
#            1       1.00      0.13      0.23      1400
#
#     accuracy                           0.93     16443
#    macro avg       0.96      0.56      0.59     16443
# weighted avg       0.93      0.93      0.90     16443
#
# [[15043     0]
#  [ 1222   178]]

# %%
#sigmoid kernel

svc_model=SVC(kernel='sigmoid')
svc_model.fit(X_train,y_train)
svc_model_y_pred=svc_model.predict(X_test)
print("f1 score : ",f1_score(y_test,svc_model_y_pred))
print(classification_report(y_test,svc_model_y_pred))
print(confusion_matrix(y_test,svc_model_y_pred))
# Out:
# f1 score :  0.22535211267605634
#               precision    recall  f1-score   support
#
#            0       0.93      0.93      0.93     15043
#            1       0.23      0.22      0.23      1400
#
#     accuracy                           0.87     16443
#    macro avg       0.58      0.58      0.58     16443
# weighted avg       0.87      0.87      0.87     16443
#
# [[14049   994]
#  [ 1096   304]]

# %%
#rbf kernel

svc_model=SVC(kernel='rbf')
svc_model.fit(X_train,y_train)
svc_model_y_pred=svc_model.predict(X_test)
print("f1 score : ",f1_score(y_test,svc_model_y_pred))
print(classification_report(y_test,svc_model_y_pred))
print(confusion_matrix(y_test,svc_model_y_pred))
# Out:
# f1 score :  0.37751004016064255
#               precision    recall  f1-score   support
#
#            0       0.93      1.00      0.97     15043
#            1       0.96      0.23      0.38      1400
#
#     accuracy                           0.93     16443
#    macro avg       0.95      0.62      0.67     16443
# weighted avg       0.94      0.93      0.92     16443
#
# [[15029    14]
#  [ 1071   329]]

# %% [markdown]
# #DECISION TREE

# %%
from sklearn.tree import DecisionTreeClassifier

dtc_model=DecisionTreeClassifier()
dtc_model.fit(X_train,y_train)
dtc_model_y_pred=dtc_model.predict(X_test)
print("f1 score : ",f1_score(y_test,dtc_model_y_pred))
print(classification_report(y_test,dtc_model_y_pred))
print(confusion_matrix(y_test,dtc_model_y_pred))
# Out:
# f1 score :  0.4289544235924933
#               precision    recall  f1-score   support
#
#            0       0.95      0.94      0.94     15043
#            1       0.40      0.46      0.43      1400
#
#     accuracy                           0.90     16443
#    macro avg       0.68      0.70      0.69     16443
# weighted avg       0.90      0.90      0.90     16443
#
# [[14099   944]
#  [  760   640]]

# %% [markdown]
# #RANDOM FOREST ALGORITHM

# %%
from sklearn.ensemble import RandomForestClassifier

rfc_model=RandomForestClassifier()
rfc_model.fit(X_train,y_train)
rfc_model_y_pred=rfc_model.predict(X_test)
print("f1 score : ",f1_score(y_test,rfc_model_y_pred))
print(classification_report(y_test,rfc_model_y_pred))
print(confusion_matrix(y_test,rfc_model_y_pred))
# Out:
# f1 score :  0.45369916707496327
#               precision    recall  f1-score   support
#
#            0       0.94      0.99      0.96     15043
#            1       0.72      0.33      0.45      1400
#
#     accuracy                           0.93     16443
#    macro avg       0.83      0.66      0.71     16443
# weighted avg       0.92      0.93      0.92     16443
#
# [[14865   178]
#  [  937   463]]

# %%
f1_score_df=pd.DataFrame({'Model':['LogisticRegression','KNeighborsClassifier','SVC','DecisionTreeClassifier','RandomForestClassifier'],
                          'f1 score':[f1_score(y_test,lr_model_y_pred),
                                      f1_score(y_test,knn_model_y_pred),
                                      f1_score(y_test,svc_model_y_pred),
                                      f1_score(y_test,dtc_model_y_pred),
                                      f1_score(y_test,rfc_model_y_pred),]})
f1_score_df
# Out:
#                     Model  f1 score
# 0      LogisticRegression  0.405844
# 1    KNeighborsClassifier  0.317811
# 2                     SVC  0.377510
# 3  DecisionTreeClassifier  0.428954
# 4  RandomForestClassifier  0.453699

# %% [markdown]
# <h3>TEST DATA</h3>

# %% [markdown]
# <h4>PREPROCESSING</h4>

# %%
test_data=pd.read_csv('test_2umaH9m.csv')

# %%
test_data
# Out:
#        employee_id         department     region         education gender  \
# 0             8724         Technology  region_26        Bachelor's      m
# 1            74430                 HR   region_4        Bachelor's      f
# 2            72255  Sales & Marketing  region_13        Bachelor's      m
# 3            38562        Procurement   region_2        Bachelor's      f
# 4            64486            Finance  region_29        Bachelor's      m
# ...            ...                ...        ...               ...    ...
# 23485        53478              Legal   region_2   Below Secondary      m
# 23486        25600         Technology  region_25        Bachelor's      m
# 23487        45409                 HR  region_16        Bachelor's      f
# 23488         1186        Procurement  region_31        Bachelor's      m
# 23489         5973         Technology  region_17  Master's & above      m
#
#       recruitment_channel  no_of_trainings  age  previous_year_rating  \
# ...

# %%
test_data[test_data.duplicated]
# Out:
# Empty DataFrame
# Columns: [employee_id, department, region, education, gender, recruitment_channel, no_of_trainings, age, previous_year_rating, length_of_service, KPIs_met >80%, awards_won?, avg_training_score]
# Index: []

# %%
employee_id_column=test_data['employee_id']
employee_id_column
# Out:
# 0         8724
# 1        74430
# 2        72255
# 3        38562
# 4        64486
#          ...
# 23485    53478
# 23486    25600
# 23487    45409
# 23488     1186
# 23489     5973
# Name: employee_id, Length: 23490, dtype: int64

# %%
test_data.drop('employee_id',axis=1,inplace=True)

# %%
#FILLING MISSING VALUES

# %%
test_data.isna().sum()
# Out:
# department                 0
# region                     0
# education               1034
# gender                     0
# recruitment_channel        0
# no_of_trainings            0
# age                        0
# previous_year_rating    1812
# length_of_service          0
# KPIs_met >80%              0
# awards_won?                0
# avg_training_score         0
# dtype: int64

# %%
test_data['education']=test_data['education'].fillna(test_data['education'].mode()[0])

# %%
test_data['previous_year_rating']=test_data['previous_year_rating'].fillna(test_data['previous_year_rating'].mode()[0])

# %%
test_data.isna().sum()
# Out:
# department              0
# region                  0
# education               0
# gender                  0
# recruitment_channel     0
# no_of_trainings         0
# age                     0
# previous_year_rating    0
# length_of_service       0
# KPIs_met >80%           0
# awards_won?             0
# avg_training_score      0
# dtype: int64

# %%
#OUTLIER DETECTION

# %%
plt.figure(figsize=(12,10))
sns.boxplot(test_data)
plt.xticks(rotation=90)
# Out:
# ([0, 1, 2, 3, 4, 5, 6],
#  [Text(0, 0, 'no_of_trainings'),
#   Text(1, 0, 'age'),
#   Text(2, 0, 'previous_year_rating'),
#   Text(3, 0, 'length_of_service'),
#   Text(4, 0, 'KPIs_met >80%'),
#   Text(5, 0, 'awards_won?'),
#   Text(6, 0, 'avg_training_score')])

# %%
sns.boxplot(test_data['age'])
# Out:
# <Axes: ylabel='age'>

# %%
q1=np.percentile(test_data['age'],25)
q3=np.percentile(test_data['age'],75)
iqr=q3-q1
upper=q3+iqr*1.5
lower=q1-iqr*1.5
outlier_list=test_data[(test_data['age']>upper)|(test_data['age']<lower)].index
column_median=test_data['age'].median()
for i in outlier_list:
  test_data.loc[i,'age']=column_median

# %%
sns.boxplot(test_data['age'])
# Out:
# <Axes: ylabel='age'>

# %%
sns.boxplot(test_data['length_of_service'])
# Out:
# <Axes: ylabel='length_of_service'>

# %%
q1=np.percentile(test_data['length_of_service'],25)
q3=np.percentile(test_data['length_of_service'],75)
iqr=q3-q1
upper=q3+iqr*1.5
lower=q1-iqr*1.5
outlier_list=test_data[(test_data['length_of_service']>upper)|(test_data['length_of_service']<lower)].index
column_median=test_data['length_of_service'].median()
for i in outlier_list:
  test_data.loc[i,'length_of_service']=column_median

# %%
sns.boxplot(test_data['length_of_service'])
# Out:
# <Axes: ylabel='length_of_service'>

# %%
#ENCODING

# %%
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23490 entries, 0 to 23489
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   department            23490 non-null  object
#  1   region                23490 non-null  object
#  2   education             23490 non-null  object
#  3   gender                23490 non-null  object
#  4   recruitment_channel   23490 non-null  object
#  5   no_of_trainings       23490 non-null  int64
#  6   age                   23490 non-null  int64
#  7   previous_year_rating  23490 non-null  float64
#  8   length_of_service     23490 non-null  int64
#  9   KPIs_met >80%         23490 non-null  int64
#  10  awards_won?           23490 non-null  int64
#  11  avg_training_score    23490 non-null  int64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 2.2+ MB

# %%
test_data.drop('region',axis=1,inplace=True)

# %%
test_data=pd.get_dummies(test_data)

# %%
test_data
# Out:
#        no_of_trainings  age  previous_year_rating  length_of_service  \
# 0                    1   24                   3.0                  1
# 1                    1   31                   3.0                  5
# 2                    1   31                   1.0                  4
# 3                    3   31                   2.0                  9
# 4                    1   30                   4.0                  7
# ...                ...  ...                   ...                ...
# 23485                1   24                   3.0                  1
# 23486                1   31                   3.0                  7
# 23487                1   26                   4.0                  4
# 23488                3   27                   3.0                  1
# 23489                3   40                   5.0                  5
#
#        KPIs_met >80%  awards_won?  avg_training_score  department_Analytics  \
# ...

# %%
#SCALING

# %%
test_data
# Out:
#        no_of_trainings  age  previous_year_rating  length_of_service  \
# 0                    1   24                   3.0                  1
# 1                    1   31                   3.0                  5
# 2                    1   31                   1.0                  4
# 3                    3   31                   2.0                  9
# 4                    1   30                   4.0                  7
# ...                ...  ...                   ...                ...
# 23485                1   24                   3.0                  1
# 23486                1   31                   3.0                  7
# 23487                1   26                   4.0                  4
# 23488                3   27                   3.0                  1
# 23489                3   40                   5.0                  5
#
#        KPIs_met >80%  awards_won?  avg_training_score  department_Analytics  \
# ...

# %%
test_data_columns=test_data.columns

# %%
test_data_columns
# Out:
# Index(['no_of_trainings', 'age', 'previous_year_rating', 'length_of_service',
#        'KPIs_met >80%', 'awards_won?', 'avg_training_score',
#        'department_Analytics', 'department_Finance', 'department_HR',
#        'department_Legal', 'department_Operations', 'department_Procurement',
#        'department_R&D', 'department_Sales & Marketing',
#        'department_Technology', 'education_Bachelor's',
#        'education_Below Secondary', 'education_Master's & above', 'gender_f',
#        'gender_m', 'recruitment_channel_other', 'recruitment_channel_referred',
#        'recruitment_channel_sourcing'],
#       dtype='object')

# %%
test_data=sc.transform(test_data)
test_data
# Out:
# array([[-0.41527615, -1.51522093, -0.25065148, ..., -1.11791466,
#         -0.14587586,  1.16635286],
#        [-0.41527615, -0.47205952, -0.25065148, ...,  0.89452266,
#         -0.14587586, -0.85737347],
#        [-0.41527615, -0.47205952, -1.89706886, ...,  0.89452266,
#         -0.14587586, -0.85737347],
#        ...,
#        [-0.41527615, -1.21717481,  0.5725572 , ..., -1.11791466,
#         -0.14587586,  1.16635286],
#        [ 2.86740293, -1.06815175, -0.25065148, ..., -1.11791466,
#         -0.14587586,  1.16635286],
#        [ 2.86740293,  0.869148  ,  1.39576589, ...,  0.89452266,
#         -0.14587586, -0.85737347]])

# %%
test_data=pd.DataFrame(test_data,columns=test_data_columns)

# %%
test_data
# Out:
#        no_of_trainings       age  previous_year_rating  length_of_service  \
# 0            -0.415276 -1.515221             -0.250651          -1.444523
# 1            -0.415276 -0.472060             -0.250651          -0.021894
# 2            -0.415276 -0.472060             -1.897069          -0.377551
# 3             2.867403 -0.472060             -1.073860           1.400734
# 4            -0.415276 -0.621083              0.572557           0.689420
# ...                ...       ...                   ...                ...
# 23485        -0.415276 -1.515221             -0.250651          -1.444523
# 23486        -0.415276 -0.472060             -0.250651           0.689420
# 23487        -0.415276 -1.217175              0.572557          -0.377551
# 23488         2.867403 -1.068152             -0.250651          -1.444523
# 23489         2.867403  0.869148              1.395766          -0.021894
#
#        KPIs_met >80%  awards_won?  avg_training_score  department_Analytics  \
# ...

# %%
f1_score_df=pd.DataFrame({'Model':['LogisticRegression','KNeighborsClassifier','SVC','DecisionTreeClassifier','RandomForestClassifier'],
                          'f1 score':[f1_score(y_test,lr_model_y_pred),
                                      f1_score(y_test,knn_model_y_pred),
                                      f1_score(y_test,svc_model_y_pred),
                                      f1_score(y_test,dtc_model_y_pred),
                                      f1_score(y_test,rfc_model_y_pred),]})
f1_score_df
# Out:
#                     Model  f1 score
# 0      LogisticRegression  0.405844
# 1    KNeighborsClassifier  0.317811
# 2                     SVC  0.377510
# 3  DecisionTreeClassifier  0.428954
# 4  RandomForestClassifier  0.453699

# %% [markdown]
# <h4>SUBMITTING DATA CREATION</h4>

# %%
submission_data=pd.read_csv('sample_submission_M0L0uXE.csv')
submission_data
# Out:
#        employee_id  is_promoted
# 0             8724            0
# 1            74430            0
# 2            72255            0
# 3            38562            0
# 4            64486            0
# ...            ...          ...
# 23485        53478            0
# 23486        25600            0
# 23487        45409            0
# 23488         1186            0
# 23489         5973            0
#
# [23490 rows x 2 columns]

# %% [markdown]
# #USING RANDOM FOREST CLASSIFIER MODEL

# %%
final_test_data_y_pred=rfc_model.predict(test_data)

# %%
final_test_data_y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
submission_data['is_promoted']=final_test_data_y_pred

# %%
submission_data
# Out:
#        employee_id  is_promoted
# 0             8724            0
# 1            74430            0
# 2            72255            0
# 3            38562            0
# 4            64486            0
# ...            ...          ...
# 23485        53478            0
# 23486        25600            0
# 23487        45409            0
# 23488         1186            0
# 23489         5973            0
#
# [23490 rows x 2 columns]

# %%
submission_data['is_promoted'].value_counts()
# Out:
# is_promoted
# 0    22595
# 1      895
# Name: count, dtype: int64

# %%
submission_data.to_csv('attempt1_rfc.csv',index=False)

# %% [markdown]
# #USING LOGISTIC REGRESSION MODEL

# %%
final_test_data_y_pred=lr_model.predict(test_data)
submission_data['is_promoted']=final_test_data_y_pred

# %%
submission_data['is_promoted'].value_counts()
# Out:
# is_promoted
# 0    22880
# 1      610
# Name: count, dtype: int64

# %%
submission_data.to_csv('attempt1_lr.csv',index=False)

# %%
submission_data
# Out:
#        employee_id  is_promoted
# 0             8724            0
# 1            74430            0
# 2            72255            0
# 3            38562            0
# 4            64486            0
# ...            ...          ...
# 23485        53478            0
# 23486        25600            0
# 23487        45409            0
# 23488         1186            0
# 23489         5973            1
#
# [23490 rows x 2 columns]

# %% [markdown]
# #USING DECISION TREE CLASSIFIER MODEL

# %%
final_test_data_y_pred=dtc_model.predict(test_data)
submission_data['is_promoted']=final_test_data_y_pred

# %%
submission_data['is_promoted'].value_counts()
# Out:
# is_promoted
# 0    21223
# 1     2267
# Name: count, dtype: int64

# %%
submission_data.to_csv('attempt1_dtc.csv',index=False)
